# %%
### Ejercicio 2

calificaciones = {
 "Ana": [17, 18, 16, 19],
 "Luis": [15, 16, 17, 16],
 "Carla": [18, 17, 19, 18],
 "Pedro": [16, 16, 16, 16],
 "Lucía": [15, 17, 16, 16]
}

estadistica = {}

for estudiante, notas in calificaciones. items()
    print(estudiante, notas)
    estadistica[estudiante] = {
        "mínima_nota": min(notas),
        "Maxima_nota": max(notas),
        "promedio": sum(notas) / len(notas)
    }   
    print('='*20)
