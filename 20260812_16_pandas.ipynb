# %%
import pandas as pd

# %%
# \Users\dpuse\OneDrive\Documentos\datascience-g8
ventas_df = pd.read_csv(
    r"C:\Users\dpuse\OneDrive\Documentos\datascience-g8\ventas.csv",
    dtype={"precio_unitario": "float64"}
)

# %%
ventas_df.head(10)
# Out:
#         fecha  region     vendedor     producto   categoria  unidades  \
# 0  2024-01-02   Oeste   Pedro Diaz  Auriculares  Accesorios         5
# 1  2024-01-02     Sur   Luis Gomez   Monitor 27  Tecnologia        14
# 2  2024-01-02  Centro  Carlos Vega   Silla Ergo  Mobiliario         1
# 3  2024-01-02  Centro   Pedro Diaz   Laptop Pro  Tecnologia        10
# 4  2024-01-03     Sur   Elena Mora  Auriculares  Accesorios         2
# 5  2024-01-03   Oeste  Javier Sanz   Escritorio  Mobiliario         2
# 6  2024-01-03   Norte  Carlos Vega   Silla Ergo  Mobiliario         4
# 7  2024-01-03   Norte   Sofia Leon   Silla Ergo  Mobiliario         1
# 8  2024-01-03  Centro  Carlos Vega   Laptop Pro  Tecnologia         1
# 9  2024-01-03  Centro   Pedro Diaz   Escritorio  Mobiliario         2
#
#    precio_unitario  descuento
# 0            130.0        0.0
# 1            320.0        0.0
# 2            280.0        0.0
# 3           1200.0        0.0
# 4            130.0        0.1
# ...

# %%
mascara = ventas_df["region"] == "Sur"
ventas_sur = ventas_df[mascara]
ventas_sur.tail()
# Out:
#            fecha region     vendedor     producto   categoria  unidades  \
# 1156  2024-12-17    Sur   Luis Gomez  Teclado Mec  Accesorios        11
# 1163  2024-12-19    Sur   Luis Gomez   Silla Ergo  Mobiliario         2
# 1181  2024-12-25    Sur   Ana Torres   Tablet Air  Tecnologia        14
# 1191  2024-12-30    Sur   Luis Gomez   Silla Ergo  Mobiliario         3
# 1192  2024-12-30    Sur  Javier Sanz  Teclado Mec  Accesorios         8
#
#       precio_unitario  descuento
# 1156             95.0       0.15
# 1163            280.0       0.00
# 1181            640.0       0.00
# 1191            280.0       0.00
# 1192             95.0       0.10

# %%
ventas_sur = ventas_df[ventas_df["region"] == "Sur"]

ventas_sur
# Out:
#            fecha region     vendedor     producto   categoria  unidades  \
# 1     2024-01-02    Sur   Luis Gomez   Monitor 27  Tecnologia        14
# 4     2024-01-03    Sur   Elena Mora  Auriculares  Accesorios         2
# 14    2024-01-05    Sur   Pedro Diaz  Teclado Mec  Accesorios        12
# 21    2024-01-07    Sur   Marta Ruiz  Auriculares  Accesorios         4
# 22    2024-01-08    Sur   Elena Mora  Teclado Mec  Accesorios         3
# ...          ...    ...          ...          ...         ...       ...
# 1156  2024-12-17    Sur   Luis Gomez  Teclado Mec  Accesorios        11
# 1163  2024-12-19    Sur   Luis Gomez   Silla Ergo  Mobiliario         2
# 1181  2024-12-25    Sur   Ana Torres   Tablet Air  Tecnologia        14
# 1191  2024-12-30    Sur   Luis Gomez   Silla Ergo  Mobiliario         3
# 1192  2024-12-30    Sur  Javier Sanz  Teclado Mec  Accesorios         8
#
#       precio_unitario  descuento
# 1               320.0       0.00
# 4               130.0       0.10
# ...

# %%
ventas_df[(ventas_df["region"] == "Sur") | (ventas_df["region"] == "Norte")]
# Out:
#            fecha region     vendedor     producto   categoria  unidades  \
# 1     2024-01-02    Sur   Luis Gomez   Monitor 27  Tecnologia        14
# 4     2024-01-03    Sur   Elena Mora  Auriculares  Accesorios         2
# 6     2024-01-03  Norte  Carlos Vega   Silla Ergo  Mobiliario         4
# 7     2024-01-03  Norte   Sofia Leon   Silla Ergo  Mobiliario         1
# 10    2024-01-04  Norte   Sofia Leon   Monitor 27  Tecnologia         3
# ...          ...    ...          ...          ...         ...       ...
# 1191  2024-12-30    Sur   Luis Gomez   Silla Ergo  Mobiliario         3
# 1192  2024-12-30    Sur  Javier Sanz  Teclado Mec  Accesorios         8
# 1194  2024-12-30  Norte   Ana Torres   Tablet Air  Tecnologia         4
# 1198  2024-12-31  Norte   Ana Torres   Monitor 27  Tecnologia         6
# 1199  2024-12-31  Norte   Marta Ruiz   Raton Ergo  Accesorios         8
#
#       precio_unitario  descuento
# 1               320.0        0.0
# 4               130.0        0.1
# ...

# %%
ventas_df.head(10)
# Out:
#         fecha  region     vendedor     producto   categoria  unidades  \
# 0  2024-01-02   Oeste   Pedro Diaz  Auriculares  Accesorios         5
# 1  2024-01-02     Sur   Luis Gomez   Monitor 27  Tecnologia        14
# 2  2024-01-02  Centro  Carlos Vega   Silla Ergo  Mobiliario         1
# 3  2024-01-02  Centro   Pedro Diaz   Laptop Pro  Tecnologia        10
# 4  2024-01-03     Sur   Elena Mora  Auriculares  Accesorios         2
# 5  2024-01-03   Oeste  Javier Sanz   Escritorio  Mobiliario         2
# 6  2024-01-03   Norte  Carlos Vega   Silla Ergo  Mobiliario         4
# 7  2024-01-03   Norte   Sofia Leon   Silla Ergo  Mobiliario         1
# 8  2024-01-03  Centro  Carlos Vega   Laptop Pro  Tecnologia         1
# 9  2024-01-03  Centro   Pedro Diaz   Escritorio  Mobiliario         2
#
#    precio_unitario  descuento
# 0            130.0        0.0
# 1            320.0        0.0
# 2            280.0        0.0
# 3           1200.0        0.0
# 4            130.0        0.1
# ...

# %%
df_filtrado = ventas_df[ventas_df["precio_unitario"].between(90, 200)]
df_filtrado
# Out:
#            fecha  region     vendedor     producto   categoria  unidades  \
# 0     2024-01-02   Oeste   Pedro Diaz  Auriculares  Accesorios         5
# 4     2024-01-03     Sur   Elena Mora  Auriculares  Accesorios         2
# 13    2024-01-05   Norte   Sofia Leon  Auriculares  Accesorios        11
# 14    2024-01-05     Sur   Pedro Diaz  Teclado Mec  Accesorios        12
# 18    2024-01-06   Oeste  Carlos Vega  Auriculares  Accesorios         2
# ...          ...     ...          ...          ...         ...       ...
# 1173  2024-12-22   Norte   Marta Ruiz  Teclado Mec  Accesorios        12
# 1177  2024-12-24   Oeste   Ana Torres  Auriculares  Accesorios        11
# 1183  2024-12-26  Centro   Luis Gomez  Auriculares  Accesorios         6
# 1189  2024-12-29   Oeste  Javier Sanz  Auriculares  Accesorios         6
# 1192  2024-12-30     Sur  Javier Sanz  Teclado Mec  Accesorios         8
#
#       precio_unitario  descuento
# 0               130.0       0.00
# ...

# %%
(ventas_df["region"]) == "Centro"
# Out:
# 0       False
# 1       False
# 2        True
# 3        True
# 4       False
#         ...
# 1195    False
# 1196    False
# 1197    False
# 1198    False
# 1199    False
# Name: region, Length: 1200, dtype: bool

# %%
len(ventas_df[(ventas_df["categoria"] == "Tecnología") & (ventas_df["unidades"] > 10)])
# Out:
# 0

# %%
ventas_df[ventas_df["descuento"] > 0]
# Out:
#            fecha  region     vendedor     producto   categoria  unidades  \
# 4     2024-01-03     Sur   Elena Mora  Auriculares  Accesorios         2
# 8     2024-01-03  Centro  Carlos Vega   Laptop Pro  Tecnologia         1
# 10    2024-01-04   Norte   Sofia Leon   Monitor 27  Tecnologia         3
# 11    2024-01-04   Oeste   Pedro Diaz   Escritorio  Mobiliario        10
# 12    2024-01-04  Centro   Marta Ruiz   Tablet Air  Tecnologia         2
# ...          ...     ...          ...          ...         ...       ...
# 1187  2024-12-28    Este   Ana Torres   Raton Ergo  Accesorios         8
# 1190  2024-12-29  Centro   Luis Gomez   Laptop Pro  Tecnologia         1
# 1192  2024-12-30     Sur  Javier Sanz  Teclado Mec  Accesorios         8
# 1196  2024-12-30    Este   Marta Ruiz   Laptop Pro  Tecnologia        13
# 1197  2024-12-31   Oeste   Ana Torres   Monitor 27  Tecnologia         2
#
#       precio_unitario  descuento
# 4               130.0       0.10
# ...
